# %% [markdown]
# # Coordinate Transformation

# %%
from src.utils import alt_az_to_l_b, l_b_to_alt_az

l_b_to_alt_az(210, 0)
# Out:
# (48.93692438308155, 217.50455606392634)

# %% [markdown]
# # Sky

# %%
from src.observation import Exposure

sky = Exposure(alt=30, az=180, type="sky", n_obs=40)
sky.run()
# Out:
# Data will be saved at [2025-08-04T14:14:22] with l=33.75939386195393, b=40.31799605553591
# Found Rafael Micro R828D tuner
# RTL-SDR Blog V4 Detected
# Exact sample rate is: 3000000.178814 Hz
# Found Rafael Micro R828D tuner
# RTL-SDR Blog V4 Detected
# Exact sample rate is: 3000000.178814 Hz
# Found Rafael Micro R828D tuner
# RTL-SDR Blog V4 Detected
# Exact sample rate is: 3000000.178814 Hz
# Found Rafael Micro R828D tuner
# RTL-SDR Blog V4 Detected
# Exact sample rate is: 3000000.178814 Hz
# Found Rafael Micro R828D tuner
# RTL-SDR Blog V4 Detected
# Exact sample rate is: 3000000.178814 Hz
# Found Rafael Micro R828D tuner
# RTL-SDR Blog V4 Detected
# Exact sample rate is: 3000000.178814 Hz
# Found Rafael Micro R828D tuner
# RTL-SDR Blog V4 Detected
# Exact sample rate is: 3000000.178814 Hz
# Found Rafael Micro R828D tuner
# RTL-SDR Blog V4 Detected
# Exact sample rate is: 3000000.178814 Hz
# Found Rafael Micro R828D tuner
# RTL-SDR Blog V4 Detected
# ...

# %% [markdown]
# # Ground

# %%
from src.observation import Exposure

ground = Exposure(type="ground", n_obs=40)
ground.run()
# Out:
# Data will be saved at [2025-08-04T14:11:14] with l=23.97870368301029, b=56.80625532668416
# Found Rafael Micro R828D tuner
# RTL-SDR Blog V4 Detected
# Exact sample rate is: 3000000.178814 Hz
# Found Rafael Micro R828D tuner
# RTL-SDR Blog V4 Detected
# Exact sample rate is: 3000000.178814 Hz
# Found Rafael Micro R828D tuner
# RTL-SDR Blog V4 Detected
# Exact sample rate is: 3000000.178814 Hz
# Found Rafael Micro R828D tuner
# RTL-SDR Blog V4 Detected
# Exact sample rate is: 3000000.178814 Hz
# Found Rafael Micro R828D tuner
# RTL-SDR Blog V4 Detected
# Exact sample rate is: 3000000.178814 Hz
# Found Rafael Micro R828D tuner
# RTL-SDR Blog V4 Detected
# Exact sample rate is: 3000000.178814 Hz
# Found Rafael Micro R828D tuner
# RTL-SDR Blog V4 Detected
# Exact sample rate is: 3000000.178814 Hz
# Found Rafael Micro R828D tuner
# RTL-SDR Blog V4 Detected
# Exact sample rate is: 3000000.178814 Hz
# Found Rafael Micro R828D tuner
# RTL-SDR Blog V4 Detected
# ...
