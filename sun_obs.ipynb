# %%
from src.observation import Exposure

sun = Exposure(alt=50, az=220, type="sun", n_obs=10)
sun.run()
# Out:
# Data will be saved at [2025-08-04T14:14:22] with l=33.75939386195393, b=40.31799605553591
# Found Rafael Micro R828D tuner
# RTL-SDR Blog V4 Detected
# Exact sample rate is: 3000000.178814 Hz
# Found Rafael Micro R828D tuner
# RTL-SDR Blog V4 Detected
# Exact sample rate is: 3000000.178814 Hz
# Found Rafael Micro R828D tuner
# RTL-SDR Blog V4 Detected
# Exact sample rate is: 3000000.178814 Hz
# Found Rafael Micro R828D tuner
# RTL-SDR Blog V4 Detected
# Exact sample rate is: 3000000.178814 Hz
# Found Rafael Micro R828D tuner
# RTL-SDR Blog V4 Detected
# Exact sample rate is: 3000000.178814 Hz
# Found Rafael Micro R828D tuner
# RTL-SDR Blog V4 Detected
# Exact sample rate is: 3000000.178814 Hz
# Found Rafael Micro R828D tuner
# RTL-SDR Blog V4 Detected
# Exact sample rate is: 3000000.178814 Hz
# Found Rafael Micro R828D tuner
# RTL-SDR Blog V4 Detected
# Exact sample rate is: 3000000.178814 Hz
# Found Rafael Micro R828D tuner
# RTL-SDR Blog V4 Detected
# ...

# %%
from src.observation import Exposure

sky = Exposure(alt=30, az=180, type="sky", n_obs=10)
sky.run()
# Out:
# Data will be saved at [2025-08-04T14:14:22] with l=33.75939386195393, b=40.31799605553591
# Found Rafael Micro R828D tuner
# RTL-SDR Blog V4 Detected
# Exact sample rate is: 3000000.178814 Hz
# Found Rafael Micro R828D tuner
# RTL-SDR Blog V4 Detected
# Exact sample rate is: 3000000.178814 Hz
# Found Rafael Micro R828D tuner
# RTL-SDR Blog V4 Detected
# Exact sample rate is: 3000000.178814 Hz
# Found Rafael Micro R828D tuner
# RTL-SDR Blog V4 Detected
# Exact sample rate is: 3000000.178814 Hz
# Found Rafael Micro R828D tuner
# RTL-SDR Blog V4 Detected
# Exact sample rate is: 3000000.178814 Hz
# Found Rafael Micro R828D tuner
# RTL-SDR Blog V4 Detected
# Exact sample rate is: 3000000.178814 Hz
# Found Rafael Micro R828D tuner
# RTL-SDR Blog V4 Detected
# Exact sample rate is: 3000000.178814 Hz
# Found Rafael Micro R828D tuner
# RTL-SDR Blog V4 Detected
# Exact sample rate is: 3000000.178814 Hz
# Found Rafael Micro R828D tuner
# RTL-SDR Blog V4 Detected
# ...

# %%
from src.observation import Exposure

ground = Exposure(alt=0, az=0, type="ground", n_obs=10)
ground.run()
# Out:
# Data will be saved at [2025-08-04T14:14:22] with l=33.75939386195393, b=40.31799605553591
# Found Rafael Micro R828D tuner
# RTL-SDR Blog V4 Detected
# Exact sample rate is: 3000000.178814 Hz
# Found Rafael Micro R828D tuner
# RTL-SDR Blog V4 Detected
# Exact sample rate is: 3000000.178814 Hz
# Found Rafael Micro R828D tuner
# RTL-SDR Blog V4 Detected
# Exact sample rate is: 3000000.178814 Hz
# Found Rafael Micro R828D tuner
# RTL-SDR Blog V4 Detected
# Exact sample rate is: 3000000.178814 Hz
# Found Rafael Micro R828D tuner
# RTL-SDR Blog V4 Detected
# Exact sample rate is: 3000000.178814 Hz
# Found Rafael Micro R828D tuner
# RTL-SDR Blog V4 Detected
# Exact sample rate is: 3000000.178814 Hz
# Found Rafael Micro R828D tuner
# RTL-SDR Blog V4 Detected
# Exact sample rate is: 3000000.178814 Hz
# Found Rafael Micro R828D tuner
# RTL-SDR Blog V4 Detected
# Exact sample rate is: 3000000.178814 Hz
# Found Rafael Micro R828D tuner
# RTL-SDR Blog V4 Detected
# ...

# %% [markdown]
# # Joint Plot

# %%
import numpy as np
import matplotlib.pyplot as plt


plt.plot(sun.freq, 10 * np.log10(sun.power))
plt.plot(sky.freq, 10 * np.log10(sky.power))
plt.plot(ground.freq, 10 * np.log10(ground.power))

plt.set_xlabel("Frequency (MHz)")
plt.set_ylabel("Power (dB/MHz)")
